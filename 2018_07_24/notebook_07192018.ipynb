# %%
from muon_h import *
from muon_plot import *

# %%
filepath = '/gpfs/slac/atlas/fs1/d/rafaeltl/public/RNNIP/FTAG_ntups/user.rateixei.mc16_13TeV.410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.AOD..dijetSamplesNominal20180629_Akt4EMTo/user.rateixei.14594351.Akt4EMTo._002365.root'

# %%
data = root2array(filepath)

# %% [markdown]
# ## 20 GeV < jet $p_T$ < 50 GeV and 0 < jet |$\eta$| < 1

# %%
makeMuonPlots(data, [20,50], [0,1], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 20 GeV < jet $p_T$ < 50 GeV and 1 < jet |$\eta$| < 2.5

# %%
makeMuonPlots(data, [20,50], [1,2.5], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 50 GeV < jet $p_T$ < 100 GeV and 0 < jet |$\eta$| < 1

# %%
makeMuonPlots(data, [50,100], [0,1], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 50 GeV < jet $p_T$ < 100 GeV and 1 < jet |$\eta$| < 2.5

# %%
makeMuonPlots(data, [50,100], [1,2.5], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 100 GeV < jet $p_T$ < 200 GeV and 0 < jet |$\eta$| < 1

# %%
makeMuonPlots(data, [100,200], [0,1], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 100 GeV < jet $p_T$ < 200 GeV and 1 < jet |$\eta$| < 2.5

# %%
makeMuonPlots(data, [100,200], [1,2.5], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 200 GeV < jet $p_T$ < 500 GeV and 0 < jet |$\eta$| < 1

# %%
makeMuonPlots(data, [200,500], [0,1], [-np.inf,np.inf], [-np.inf,np.inf])

# %% [markdown]
# ## 200 GeV < jet $p_T$ < 500 GeV and 1 < jet |$\eta$| < 2.5

# %%
makeMuonPlots(data, [200,500], [1,2.5], [-np.inf,np.inf], [-np.inf,np.inf])
