# %% [markdown]
# # SMT studies for muons from light-flavoured jets

# %% [markdown]
# #### Jet Cuts:
# ####     - Calibrated jet $p_T$ > 20 GeV/c, |$\eta$| < 2.5
# ####     - JVT > 0.59 low $p_T$ jets
# ####     - Jet can't overlap with a previously IDed photon or muon
# #### Muon Cuts:
# ####     - Muon $p_T$ > 1 GeV/c, |$\eta$| < 2.5

# %%
branchNames = [
    "jet_LabDr_HadF",
    "jet_pt",
    "jet_eta",
    "jet_phi",
    "jet_JVT",
    "jet_aliveAfterOR",
    "jet_aliveAfterORmu",
    "jet_mu_smt",
    "jet_mu_pt",
    "jet_mu_eta",
    "jet_mu_phi",
    "jet_mu_pTrel",
    "jet_mu_dR",
    "jet_mu_d0",
    "jet_mu_z0",
    "jet_mu_parent_pdgid",
    "jet_mu_qOverPratio"
]

# %%
import glob
import numpy as np
from root_numpy import root2array

files = glob.glob("/gpfs/slac/atlas/fs1/d/rafaeltl/public/RNNIP/FTAG_ntups/user.bdong.perf-flavtag.mc16_13TeV.410470.ttbar_nonallhad.e6337_e5984_s3126_r10201_r10210_Akt4EMTo/*.root")
data = root2array(files[0], branches=branchNames)
print "Added ntuple #1"

for f in range(1,len(files)):
    data = np.hstack((data,root2array(files[f], branches=branchNames)))
    print "Added ntuple #{}".format(f+1)

# %%
from muon_plot import *

# %%
lightFlavourPlots = makeMuonLightFlavourPlots(data)

# %%
printMuonPlots(lightFlavourPlots)
