# %% [markdown]
# # SMT Studies

# %% [markdown]
# #### Jet Cuts:
# ####     - Calibrated jet $p_T$ > 29 GeV/c, |$\eta$| < 2.5
# ####     - JVT > 0.59 low $p_T$ jets
# ####     - Jet can't overlap with a previously IDed photon or muon
# #### Muon Cuts:
# ####     - Muon $p_T$ > 1 GeV/c, |$\eta$| < 2.5

# %%
branchNames = [
    "jet_LabDr_HadF",
    "jet_pt",
    "jet_eta",
    "jet_JVT",
    "jet_aliveAfterOR",
    "jet_aliveAfterORmu",
    "jet_mu_smt",
    "jet_mu_pt",
    "jet_mu_eta",
    "jet_mu_pTrel",
    "jet_mu_dR",
    "jet_mu_d0",
    "jet_mu_z0",
    "jet_mu_parent_pdgid"
]

# %%
fileName = "/gpfs/slac/atlas/fs1/d/rafaeltl/public/RNNIP/FTAG_ntups/user.bdong.perf-flavtag.mc16_13TeV.410470.ttbar_nonallhad.e6337_e5984_s3126_r10201_r10210_Akt4EMTo/user.bdong.13791488.Akt4EMTo._000002.root"

# %%
import numpy as np
from root_numpy import root2array

# %%
data = root2array(fileName, branches=branchNames)

# %%
from muon_plot import *

# %%
jetTypePlots = makeMuonJetTypePlots(data)

# %%
printMuonPlots(jetTypePlots)
