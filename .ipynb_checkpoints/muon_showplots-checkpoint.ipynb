# %%
from muon_h import *
from muon_plot import *

# %%
filepath = '/gpfs/slac/atlas/fs1/d/rafaeltl/public/RNNIP/FTAG_ntups/user.rateixei.mc16_13TeV.410470.PhPy8EG_A14_ttbar_hdamp258p75_nonallhad.AOD..dijetSamplesNominal20180629_Akt4EMTo/user.rateixei.14594351.Akt4EMTo._002365.root'

# %%
data = root2array(filepath)

# %% [markdown]
# ## $20~\textrm{GeV} \leq \textrm{Jet } p_{T} < 50~\textrm{GeV} \textrm{ and } 0 \leq  \textrm{Jet} \left|\eta\right| < 1$

# %%
makeMuonPlots(data,"20_50","0_1")

# %% [markdown]
# ## $20~\textrm{GeV} \leq \textrm{Jet } p_{T} < 50~\textrm{GeV} \textrm{ and } 1 \leq  \textrm{Jet} \left|\eta\right| < 2.5$

# %%
makeMuonPlots(data,"20_50","1_2.5")

# %% [markdown]
# ## $50~\textrm{GeV} \leq \textrm{Jet } p_{T} < 100~\textrm{GeV} \textrm{ and } 0 \leq  \textrm{Jet} \left|\eta\right| < 1$

# %%
makeMuonPlots(data,"50_100","0_1")

# %% [markdown]
# ## $50~\textrm{GeV} \leq \textrm{Jet } p_{T} < 100~\textrm{GeV} \textrm{ and } 1 \leq  \textrm{Jet} \left|\eta\right| < 2.5$

# %%
makeMuonPlots(data,"50_100","1_2.5")

# %% [markdown]
# ## $100~\textrm{GeV} \leq \textrm{Jet } p_{T} < 200~\textrm{GeV} \textrm{ and } 0 \leq  \textrm{Jet} \left|\eta\right| < 1$

# %%
makeMuonPlots(data,"100_200","0_1")

# %% [markdown]
# ## $100~\textrm{GeV} \leq \textrm{Jet } p_{T} < 200~\textrm{GeV} \textrm{ and } 1 \leq  \textrm{Jet} \left|\eta\right| < 2.5$

# %%
makeMuonPlots(data,"100_200","1_2.5")

# %% [markdown]
# ## $200~\textrm{GeV} \leq \textrm{Jet } p_{T} < 500~\textrm{GeV} \textrm{ and } 0 \leq  \textrm{Jet} \left|\eta\right| < 1$

# %%
makeMuonPlots(data,"200_500","0_1")

# %% [markdown]
# ## $200~\textrm{GeV} \leq \textrm{Jet } p_{T} < 500~\textrm{GeV} \textrm{ and } 1 \leq  \textrm{Jet} \left|\eta\right| < 2.5$

# %%
makeMuonPlots(data,"200_500","1_2.5")
